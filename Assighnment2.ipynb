# %% [markdown]
# <a href="https://colab.research.google.com/github/LatifaAlnaim1996/LatifaAssighnment/blob/main/Assighnment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Assighnment2 , Rain Prediction**

# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/gumdropsteve/datasets/master/seattle_weather_1948-2017.csv')

df
# Out:
#                ds  prcp  tmax  tmin   rain
# 0      1948-01-01  0.47    51    42   True
# 1      1948-01-02  0.59    45    36   True
# 2      1948-01-03  0.42    45    35   True
# 3      1948-01-04  0.31    45    34   True
# 4      1948-01-05  0.17    45    32   True
# ...           ...   ...   ...   ...    ...
# 25546  2017-12-10  0.00    49    34  False
# 25547  2017-12-11  0.00    49    29  False
# 25548  2017-12-12  0.00    46    32  False
# 25549  2017-12-13  0.00    48    34  False
# 25550  2017-12-14  0.00    50    36  False
#
# [25551 rows x 5 columns]

# %%
df['prcp'].value_counts()
# Out:
# 0.00    14648
# 0.01      933
# 0.02      707
# 0.03      493
# 0.04      428
#         ...
# 2.49        1
# 2.18        1
# 2.20        1
# 2.70        1
# 2.95        1
# Name: prcp, Length: 207, dtype: int64

# %%
df['prcp'].loc[df['prcp'] < 2].plot(kind='hist');

# %%
df['prcp'].plot(kind='hist');

# %%
df['prcp'].loc[(df['prcp'] > 3.5) & (df['prcp'] < 5)].plot(kind='hist');

# %%
df.loc[df['prcp'].isna()==True]
# Out:
#                ds  prcp  tmax  tmin rain
# 18415  1998-06-02   NaN    72    52  NaN
# 18416  1998-06-03   NaN    66    51  NaN
# 21067  2005-09-05   NaN    70    52  NaN

# %%
import seaborn as sns

sns.boxplot(data=df)

# %%
import numpy as np

# what % of days did it rain?
np.sum(df['rain']) / len(df) * 100
# Out:
# 42.659778482251184

# %%
df = df.loc[df['rain'].isna()==False]
df
# Out:
#                ds  prcp  tmax  tmin   rain
# 0      1948-01-01  0.47    51    42   True
# 1      1948-01-02  0.59    45    36   True
# 2      1948-01-03  0.42    45    35   True
# 3      1948-01-04  0.31    45    34   True
# 4      1948-01-05  0.17    45    32   True
# ...           ...   ...   ...   ...    ...
# 25546  2017-12-10  0.00    49    34  False
# 25547  2017-12-11  0.00    49    29  False
# 25548  2017-12-12  0.00    46    32  False
# 25549  2017-12-13  0.00    48    34  False
# 25550  2017-12-14  0.00    50    36  False
#
# [25548 rows x 5 columns]

# %%
sns.boxplot(data=df['rain'])

# %%
df.loc[(df.tmax<90) & (df.tmin>17)]
# Out:
#                ds  prcp  tmax  tmin   rain
# 0      1948-01-01  0.47    51    42   True
# 1      1948-01-02  0.59    45    36   True
# 2      1948-01-03  0.42    45    35   True
# 3      1948-01-04  0.31    45    34   True
# 4      1948-01-05  0.17    45    32   True
# ...           ...   ...   ...   ...    ...
# 25546  2017-12-10  0.00    49    34  False
# 25547  2017-12-11  0.00    49    29  False
# 25548  2017-12-12  0.00    46    32  False
# 25549  2017-12-13  0.00    48    34  False
# 25550  2017-12-14  0.00    50    36  False
#
# [25225 rows x 5 columns]

# %%
sns.pairplot(df[['tmax', 'tmin', 'prcp']])

# %%
train = df.head(20179)

test = df.tail(len(df) - 20179)

train
# Out:
#                ds  prcp  tmax  tmin   rain
# 0      1948-01-01  0.47    51    42   True
# 1      1948-01-02  0.59    45    36   True
# 2      1948-01-03  0.42    45    35   True
# 3      1948-01-04  0.31    45    34   True
# 4      1948-01-05  0.17    45    32   True
# ...           ...   ...   ...   ...    ...
# 20176  2003-03-29  0.00    65    44  False
# 20177  2003-03-30  0.18    66    47   True
# 20178  2003-03-31  0.09    56    46   True
# 20179  2003-04-01  0.17    49    38   True
# 20180  2003-04-02  0.11    50    34   True
#
# [20179 rows x 5 columns]

# %%
print(len(df))

df = df.loc[df.tmax>20]

len(df)
# Out:
# 25548
# 25538

# %%
df.tmax.value_counts()[-5:]
# Out:
# 23     5
# 99     3
# 21     3
# 100    1
# 103    1
# Name: tmax, dtype: int64

# %%
sns.pairplot(df[['tmax', 'tmin', 'prcp']])
